# %%
import datasets
import pandas as pd
from inltk.inltk import setup, get_similar_sentences

# %%
data = datasets.load_dataset("raygx/NepCov19Tweets")
data = pd.DataFrame(data['train'])
data
# Out:
# Using custom data configuration raygx--NepCov19Tweets-1707432c5a916c5c
# Reusing dataset parquet (C:\Users\Dell\.cache\huggingface\datasets\raygx___parquet\raygx--NepCov19Tweets-1707432c5a916c5c\0.0.0\2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]
#        Sentiment                                          Sentences
# 0             -1  अमेरिकामा कोभिड बाट एकै दिन चार हजारभन्दा बढीक...
# 1             -1  कोभिड का कारण विदेशमा रहेका नेपालीहरुमा मानसिक...
# 2              1  नेपालमा क्लोभर बायोफार्मास्युटिकल्स अस्ट्रेलिय...
# 3              0                            कोभिड को खोप पनि लगाइयो
# 4             -1  अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजारभन्...
# ...          ...                                                ...
# 33466          0  कोरोना भाइरसलाई विश्व स्वास्थ्य संगठनले दियो न...
# 33467          0       डब्ल्युएचओले दियाेको कोरोनाको नयाँ नाम कोभिड
# 33468          0        कोरोना भाइरस संक्रमणको औपचारिक नाम अब कोभिड
# 33469          0  विश्व स्वास्थ्य संगठन डब्लुएचओ ले नोबल कोरोना ...
# 33470          0  कोरोनाभाइरसका सङ्क्रमणको नाम कोभिड भनेर विश्व ...
#
# [33471 rows x 2 columns]

# %%
neutral = data[data['Sentiment'] == 0]
neutral
# Out:
#        Sentiment                                          Sentences
# 3              0                            कोभिड को खोप पनि लगाइयो
# 7              0          रामेछापमा कोभिड सङ्क्रमितको संख्या पुग्यो
# 9              0  स्वास्थ्य मन्त्रालयले माग्यो कोभिड को रोकथामका...
# 13             0  कोभिड अहिले पनि छ हामीले अहिले पनि सामाजिक दुर...
# 15             0  संयुक्त राज्य अमेरिकामा कोभिड को मृत्युमा नयाँ...
# ...          ...                                                ...
# 33466          0  कोरोना भाइरसलाई विश्व स्वास्थ्य संगठनले दियो न...
# 33467          0       डब्ल्युएचओले दियाेको कोरोनाको नयाँ नाम कोभिड
# 33468          0        कोरोना भाइरस संक्रमणको औपचारिक नाम अब कोभिड
# 33469          0  विश्व स्वास्थ्य संगठन डब्लुएचओ ले नोबल कोरोना ...
# 33470          0  कोरोनाभाइरसका सङ्क्रमणको नाम कोभिड भनेर विश्व ...
#
# [4871 rows x 2 columns]
