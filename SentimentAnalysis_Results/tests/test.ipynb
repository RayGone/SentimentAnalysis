# %%
import datasets
from datasets import concatenate_datasets

data = datasets.load_dataset("raygx/NepCov19Tweets")
# data = concatenate_datasets([data['train'],data['test']])
data
# Out:
# Found cached dataset parquet (C:/Users/Dell/.cache/huggingface/datasets/raygx___parquet/raygx--NepCov19Tweets-11ff376905985191/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Sentiment', 'Sentences'],
#         num_rows: 33471
#     })
# })

# %%
import pandas as pd
import gc

data = pd.DataFrame({"label":data['train']['Sentiment'],"tweets":data['train']['Sentences']})
gc.collect()
data
# Out:
#        label                                             tweets
# 0         -1  अमेरिकामा कोभिड बाट एकै दिन चार हजारभन्दा बढीक...
# 1         -1  कोभिड का कारण विदेशमा रहेका नेपालीहरुमा मानसिक...
# 2          1  नेपालमा क्लोभर बायोफार्मास्युटिकल्स अस्ट्रेलिय...
# 3          0                            कोभिड को खोप पनि लगाइयो
# 4         -1  अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजारभन्...
# ...      ...                                                ...
# 33466      0  कोरोना भाइरसलाई विश्व स्वास्थ्य संगठनले दियो न...
# 33467      0       डब्ल्युएचओले दियाेको कोरोनाको नयाँ नाम कोभिड
# 33468      0        कोरोना भाइरस संक्रमणको औपचारिक नाम अब कोभिड
# 33469      0  विश्व स्वास्थ्य संगठन डब्लुएचओ ले नोबल कोरोना ...
# 33470      0  कोरोनाभाइरसका सङ्क्रमणको नाम कोभिड भनेर विश्व ...
#
# [33471 rows x 2 columns]

# %%
for x in data[data['label']==-1][:100]['tweets']:
    print(x)
# Out:
# अमेरिकामा कोभिड बाट एकै दिन चार हजारभन्दा बढीको मृत्यु
# कोभिड का कारण विदेशमा रहेका नेपालीहरुमा मानसिक स्वास्थ्य सम्बन्धि समस्या देखिएको र आत्महत्याका घटनाहरु बढेको डा सापकोटाले बताए
# अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजारभन्दा बढीको मृत्यु विश्व समाचार
# गण्डकी प्रदेश सरकारले कोभिड बाट प्रभावीतहरुको लागि भनेर स्थापित व्यवसाय जीवन रक्षा कोषमा अर्ब छुट्याइएकोमा महिना लागि सक्दा पनि कार्यविधि समेत बनेको छैन यसबाट बजेट कार्यन्वयनको पक्ष कस्तो छ अनुमान लगाउन सकिन्छ
# नेपालको संचार अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजारभन्दा बढीको मृत्यु
# अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजार भन्दा बढीको ज्यान गयो
# संयुक्त राज्य अमेरिकामा कोभिड को कारण मानिसको मृत्युमा नयाँ रेकर्ड देखिएको छ
# अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिनमा चार हजारभन्दा बढीको मृत्यु
# अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजार बढीको मृत्यु
# कोभिड सङ्क्रमणबाट विदेशमा थप तीन जना नेपालीको निधन
# ...
